# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

# Load the audio file
audio_path = 'D:/project/Marathwada Voice/m3-converted.wav'
y, sr = librosa.load(audio_path)

# Plot the waveform
plt.figure(figsize=(12, 6))
librosa.display.waveshow(y, sr=sr)
plt.title('Waveform')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

# Compute and plot the spectrogram
D = librosa.amplitude_to_db(librosa.stft(y), ref=np.max)
plt.figure(figsize=(12, 6))
librosa.display.specshow(D, sr=sr, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram')
plt.show()

# Compute MFCCs
mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)

# Plot MFCCs
plt.figure(figsize=(12, 6))
librosa.display.specshow(mfccs, sr=sr, x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.ylabel('MFCC Coefficient Index')
plt.xlabel('Time (s)')
plt.show()
# Out:
# C:\Users\pjmod\AppData\Local\Temp\ipykernel_20968\2598662629.py:18: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   D = librosa.amplitude_to_db(librosa.stft(y), ref=np.max)

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

# Load the audio file
audio_path = 'D:/project/Vidharbha Voice/v28-converted.wav'
y, sr = librosa.load(audio_path)

# Plot the waveform
plt.figure(figsize=(12, 6))
librosa.display.waveshow(y, sr=sr)
plt.title('Waveform')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

# Compute and plot the spectrogram
D = librosa.amplitude_to_db(librosa.stft(y), ref=np.max)
plt.figure(figsize=(12, 6))
librosa.display.specshow(D, sr=sr, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram')
plt.show()

# Compute MFCCs
mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)

# Plot MFCCs
plt.figure(figsize=(12, 6))
librosa.display.specshow(mfccs, sr=sr, x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.ylabel('MFCC Coefficient Index')
plt.xlabel('Time (s)')
plt.show()
# Out:
# C:\Users\pjmod\AppData\Local\Temp\ipykernel_20968\2165037399.py:18: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   D = librosa.amplitude_to_db(librosa.stft(y), ref=np.max)
